# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
#Read whale returns and create Dataframe and identify # of rows/columns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_returns_csv)
whale_returns = pd.read_csv(whale_returns_csv, index_col = "Date", infer_datetime_format=True, parse_dates=True)
whale_returns.shape
# Out:
# (1060, 4)

# %%
#Drop nulls and sort ascending dates
clean_whale_returns = whale_returns.sort_index(axis=0, ascending = True)
clean_whale_returns.dropna(inplace=True)
clean_whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
#Confirm zero 'Nulls'
clean_whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Read algo returns create Dataframe and identify # of rows/columns 
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_csv, index_col = "Date", infer_datetime_format=True, parse_dates=True)
algo_returns.shape
# Out:
# (1241, 2)

# %%
# Drop nulls and sort ascending dates
clean_algo_returns = algo_returns.sort_index(axis=0, ascending=True)
clean_algo_returns.dropna(inplace=True)
clean_algo_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
#Confirm zero nulls
clean_algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
#Read S&P 500 read Dataframe and identify # of rows and columns
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_history.shape
# Out:
# (1649, 1)

# %%
#Sort index and drop nulls
sp500_history.sort_index(axis=0, ascending=True, inplace=True)
sp500_history.dropna(inplace=True)
sp500_history.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
#Check datatypes
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history['Close'] = sp500_history['Close'].str.replace('$', '')
sp500_history["Close"] = sp500_history["Close"].astype("float")
sp500_history["Close"].dtype
# Out:
# dtype('float64')

# %%
#Calculate Daily Returns and Drop nulls
sp500_daily_returns = sp500_history.pct_change()
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
#Check for '0' nulls
sp500_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
#Rename column S&P 500
clean_sp500_daily_returns = sp500_daily_returns.rename(columns = {"Close" : "S&P 500"})
clean_sp500_daily_returns.tail()
# Out:
#              S&P 500
# Date
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841

# %%
#Concatenate all Dataframes into a single Dataframe
all_returns = pd.concat([clean_whale_returns,clean_algo_returns,clean_sp500_daily_returns], axis='columns', join='inner')
all_returns.sort_index(axis=0, ascending=True, inplace=True)
all_returns.dropna(inplace=True)
all_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# 2015-03-09  0.001303  0.003944

# %%
#Plot Daily Returns
all_returns.plot(figsize=(20,10))

# %%
#Plot Cumulative Returns
cumulative_returns = (1 + all_returns).cumprod() -1
cumulative_returns.plot(figsize=(20,10))

# %%
# Box plot to visually show risk
all_returns.plot.box(figsize=(20,10))

# %%
#Calculate the std dev. for each portfolio
daily_std = all_returns.std()
print(daily_std)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
#Determine which portfolios are riskier than the S&P 500
risky_stocks = daily_std[daily_std > daily_std["S&P 500"]]
print(risky_stocks)
# Out:
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %%
#Calculate annualized std dev. (252 trading days)
std_annual = daily_std * np.sqrt(252)
print(std_annual)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %%
# Calculate and plot the rolling standard deviation for the S&P 500 and whale portfolios using a 21 trading day window
all_returns.rolling(window=21).std().plot(figsize=(20,10))

# %%
#Construct correlation table
import seaborn as sns
correlation = all_returns.corr()
sns.heatmap(correlation, vmin=-1, vmax=1)
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# Algo 2                                          0.507414
# S&P 500                                         0.623946
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754360  0.321211  0.826873
# PAULSON & CO.INC.                          0.545623  0.268840  0.678152
# TIGER GLOBAL MANAGEMENT LLC                0.424423  0.164387  0.507414
# BERKSHIRE HATHAWAY INC                     1.000000  0.292033  0.688082
# Algo 1                                     0.292033  1.000000  0.288243
# Algo 2                                     0.688082  0.288243  1.000000
# S&P 500                                    0.751371  0.279494  0.858764
#
#                               S&P 500
# SOROS FUND MANAGEMENT LLC    0.837864
# PAULSON & CO.INC.            0.669732
# TIGER GLOBAL MANAGEMENT LLC  0.623946
# BERKSHIRE HATHAWAY INC       0.751371
# Algo 1                       0.279494
# Algo 2                       0.858764
# S&P 500                      1.000000

# %%
#Calculate Beta for a Algo 2 portfolio compared to the total market(S&P 500)
covariance = all_returns["Algo 2"].rolling(window=90).cov(all_returns["S&P 500"])
variance = all_returns["S&P 500"].rolling(window=90).var()
algo2_beta = (covariance / variance)
fig_algo2_beta = algo2_beta.plot()

# %%
# Calculate S&P Beta compared to Algo 2 beta above
covariance = all_returns["S&P 500"].rolling(window=90).cov(all_returns["Algo 2"])
variance = all_returns["Algo 2"].rolling(window=90).var()
sp500_beta = (covariance / variance)
fig_sp500_beta = sp500_beta.plot()

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
rolling_EWM = all_returns.ewm(halflife=21).mean().plot()

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratio = (all_returns.mean() * 252) / (all_returns.std() * np.sqrt(252))
sharpe_ratio.sort_values()
# Out:
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# SOROS FUND MANAGEMENT LLC      0.356417
# Algo 2                         0.501364
# BERKSHIRE HATHAWAY INC         0.621810
# S&P 500                        0.648267
# Algo 1                         1.378648
# dtype: float64

# %%
#Visualize the Sharpe Ratio as a bar plot
sharpe_ratio.plot.bar()

# %%
# Read the first stock
# YOUR CODE HERE

cost_data = Path("Resources/cost_historical.csv")
cost = pd.read_csv(cost_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Read the second stock
# YOUR CODE HERE

goog_data = Path("Resources/goog_historical.csv")
goog = pd.read_csv(goog_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
goog.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Read the third stock
# YOUR CODE HERE

aapl_data = Path("Resources/aapl_historical.csv")
aapl = pd.read_csv(aapl_data, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
aapl.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE

# Create a new pivot table where the columns are the closing prices for each ticker
portfolio_df = pd.concat([cost, goog, aapl], axis="columns", join="inner")
portfolio_df.head()
# Out:
#            Symbol    NOCP Symbol     NOCP Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47   GOOG  1162.38   AAPL  200.72
# 2019-05-08   COST  241.34   GOOG  1166.27   AAPL  202.90
# 2019-05-07   COST  240.18   GOOG  1174.10   AAPL  202.86
# 2019-05-06   COST  244.23   GOOG  1189.39   AAPL  208.48
# 2019-05-03   COST  244.62   GOOG  1185.40   AAPL  211.75

# %%
#Drop 'Symbol' add ticker symbol to columns
portfolio_df.drop(columns=['Symbol'], inplace=True)
portfolio_df.columns=['COST','GOOG','AAPL']
portfolio_df.head()
# Out:
#               COST     GOOG    AAPL
# Trade DATE
# 2019-05-09  243.47  1162.38  200.72
# 2019-05-08  241.34  1166.27  202.90
# 2019-05-07  240.18  1174.10  202.86
# 2019-05-06  244.23  1189.39  208.48
# 2019-05-03  244.62  1185.40  211.75

# %%
# Reset the index
# YOUR CODE HERE
portfolio_df = portfolio_df.reset_index()
portfolio_df.head()
# Out:
#   Trade DATE    COST     GOOG    AAPL
# 0 2019-05-09  243.47  1162.38  200.72
# 1 2019-05-08  241.34  1166.27  202.90
# 2 2019-05-07  240.18  1174.10  202.86
# 3 2019-05-06  244.23  1189.39  208.48
# 4 2019-05-03  244.62  1185.40  211.75

# %%
# Pivot the Data so that the stock tickers are the columns, the dates are the index, and the 
# values are the closing prices
# YOUR CODE HERE

portfolio_df = portfolio_df.pivot_table(index="Trade DATE")
portfolio_df.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Drop Nulls
# YOUR CODE HERE

portfolio_df = portfolio_df.dropna()
portfolio_df.isnull().sum()
# Out:
# AAPL    0
# COST    0
# GOOG    0
# dtype: int64

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
daily_returns = portfolio_df.pct_change()
daily_returns.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940

# %%
weights = [0.33, 0.33, 0.33]
weighted_returns = daily_returns.dot(weights)
weighted_returns.head()
# Out:
# Trade DATE
# 2018-05-11         NaN
# 2018-05-14    0.000015
# 2018-05-15   -0.009963
# 2018-05-16    0.009309
# 2018-05-17   -0.001579
# dtype: float64

# %%
# Join Portfolio returns to the df that contains all portfolio returns

combined_df = pd.concat([all_returns, daily_returns], axis="columns", join ="inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2   S&P 500      AAPL      COST      GOOG
# 2018-05-11  0.000281  0.001708       NaN       NaN       NaN
# 2018-05-14  0.001635  0.000884 -0.002333  0.000613  0.001766
# 2018-05-15 -0.001139 -0.006842 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.003341  0.004061  0.009333  0.016523  0.002354
# 2018-05-17  0.005205 -0.000856 -0.006324  0.004479 -0.002940

# %%
#Drop nulls
combined_df = combined_df.dropna()
combined_df.isnull().sum()
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500      AAPL      COST      GOOG
# 2018-05-14  0.001635  0.000884 -0.002333  0.000613  0.001766
# 2018-05-15 -0.001139 -0.006842 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.003341  0.004061  0.009333  0.016523  0.002354
# 2018-05-17  0.005205 -0.000856 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.002496 -0.002632 -0.003637 -0.003206 -0.011339

# %%
#Risk 
#Find std dev of combined dataframe
combined_std = combined_df.std()
combined_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.009240
# PAULSON & CO.INC.              0.007353
# TIGER GLOBAL MANAGEMENT LLC    0.014648
# BERKSHIRE HATHAWAY INC         0.015569
# Algo 1                         0.008423
# Algo 2                         0.008791
# S&P 500                        0.009578
# AAPL                           0.018706
# COST                           0.013357
# GOOG                           0.016095
# dtype: float64

# %%
#sort std dev. to find order of risk
combined_std_sort = combined_std.sort_values(ascending=False)
combined_std_sort.head(10)
# Out:
# AAPL                           0.018706
# GOOG                           0.016095
# BERKSHIRE HATHAWAY INC         0.015569
# TIGER GLOBAL MANAGEMENT LLC    0.014648
# COST                           0.013357
# S&P 500                        0.009578
# SOROS FUND MANAGEMENT LLC      0.009240
# Algo 2                         0.008791
# Algo 1                         0.008423
# PAULSON & CO.INC.              0.007353
# dtype: float64

# %%
#annualize the riskiness
combined_std_annual = combined_std * np.sqrt(252)
combined_std_annual.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# Algo 2                         0.139556
# S&P 500                        0.152054
# AAPL                           0.296951
# COST                           0.212034
# GOOG                           0.255500
# dtype: float64

# %%
#Rolling
rolling_combined_std = combined_df.rolling(window=21).std()
rolling_combined_std = rolling_combined_std.plot(figsize=(20,10), title="Rolling 21-Day Std Dev")

# %%
#Beta
#Find variance for combined portfolio vs. S&P 500.
#Find covariance for all stocks then find beta for all stocks
variance = combined_df["S&P 500"].var()
print(variance)
# Out:
# 9.17475896298873e-05

# %%
cov_soros = combined_df['SOROS FUND MANAGEMENT LLC'].cov(combined_df["S&P 500"])
cov_soros
# Out:
# 7.761473618592386e-05

# %%
beta_soros = cov_soros / variance
beta_soros
# Out:
# 0.8459594033916769

# %%
cov_paulson = combined_df['PAULSON & CO.INC. '].cov(combined_df["S&P 500"])
cov_paulson
# Out:
# 5.4000885778888475e-05

# %%
beta_paulson = cov_paulson / variance
beta_paulson
# Out:
# 0.5885809752248508

# %%
cov_tiger = combined_df['TIGER GLOBAL MANAGEMENT LLC'].cov(combined_df['S&P 500'])
cov_tiger
# Out:
# 6.749162618669418e-05

# %%
beta_tiger = cov_tiger / variance
beta_tiger
# Out:
# 0.7356228807640348

# %%
cov_berkshire = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df['S&P 500'])
cov_berkshire
# Out:
# 0.00012710419597686091

# %%
beta_berkshire = cov_berkshire / variance
beta_berkshire
# Out:
# 1.3853682313573936

# %%
cov_algo1 = combined_df['Algo 1'].cov(combined_df['S&P 500'])
cov_algo1
# Out:
# 2.3344034698704812e-05

# %%
beta_algo1 = cov_algo1 / variance
beta_algo1
# Out:
# 0.2544375802446189

# %%
cov_algo2 = combined_df['Algo 2'].cov(combined_df['S&P 500'])
cov_algo2
# Out:
# 7.374156856642586e-05

# %%
beta_algo2 = cov_algo2 / variance
beta_algo2
# Out:
# 0.8037439333709113

# %%
cov_aapl = combined_df['AAPL'].cov(combined_df['S&P 500'])
cov_aapl
# Out:
# 0.00013615807352982602

# %%
beta_appl = cov_aapl / variance
beta_appl
# Out:
# 1.4840506881880169

# %%
cov_cost = combined_df['COST'].cov(combined_df['S&P 500'])
cov_cost
# Out:
# 7.552203969385283e-05

# %%
beta_cost = cov_cost / variance
beta_cost
# Out:
# 0.8231501230551249

# %%
cov_goog = combined_df['GOOG'].cov(combined_df['S&P 500'])
cov_goog
# Out:
# 0.0001221100976265112

# %%
beta_goog = cov_goog / variance
beta_goog
# Out:
# 1.3309352116944677

# %%
for column in combined_df.columns:
    print(column)
# Out:
# SOROS FUND MANAGEMENT LLC
# PAULSON & CO.INC.
# TIGER GLOBAL MANAGEMENT LLC
# BERKSHIRE HATHAWAY INC
# Algo 1
# Algo 2
# S&P 500
# AAPL
# COST
# GOOG

# %%
#sharpe = combined_df.mean()*252 / combined_std_annual

#combined_cov = combined_df["SOROS FUND MANAGEMENT LLC", 
                           "PAULSON & CO.INC.", 
                           "TIGER GLOBAL MANAGEMENT LLC", 
                           "BERKSHIRE HATHAWAY INC", "Algo 1", "Algo 2", "S&P 500", "AAPL", "COST", "GOOG"]
#combined_cov = combined_df.cov(all_returns)
#.cov(all_returns["S&P 500"]
#variance = all_returns["S&P 500"].var()
#combined_beta = (combined_cov / variance)
#print(combined_beta)
# Out:
#   File "<ipython-input-85-404a0d795ed8>", line 4
#     "PAULSON & CO.INC.",
#     ^
# IndentationError: unexpected indent

# %%
#Annualized Sharpe Ratios (using 'mean' and 'std' functions)
sharpe_ratio = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P 500                        0.584820
# AAPL                           0.490850
# COST                           1.244419
# GOOG                           0.714034
# dtype: float64

# %%
#Visualize sharpe ratio as bar plot
sharpe_ratio.plot(kind="bar", figsize=(20,10))

# %%
#Correlation analysis
correlation = combined_df.corr()
sns.heatmap(correlation, vmin=-1, vmax=1)
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791962
# PAULSON & CO.INC.                             0.791962            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.478627            0.485375
# BERKSHIRE HATHAWAY INC                        0.816675            0.650758
# Algo 1                                        0.337826            0.361301
# Algo 2                                        0.862846            0.783656
# S&P 500                                       0.876981            0.766680
# AAPL                                          0.609126            0.544949
# COST                                          0.518175            0.496810
# GOOG                                          0.682919            0.554123
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.478627
# PAULSON & CO.INC.                               0.485375
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.325457
# Algo 1                                          0.114554
# Algo 2                                          0.409496
# S&P 500                                         0.481030
# AAPL                                            0.334864
# COST                                            0.353235
# GOOG                                            0.291055
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.816675  0.337826  0.862846
# PAULSON & CO.INC.                          0.650758  0.361301  0.783656
# TIGER GLOBAL MANAGEMENT LLC                0.325457  0.114554  0.409496
# BERKSHIRE HATHAWAY INC                     1.000000  0.327000  0.782804
# Algo 1                                     0.327000  1.000000  0.365512
# Algo 2                                     0.782804  0.365512  1.000000
# S&P 500                                    0.852303  0.289358  0.875721
# AAPL                                       0.694062  0.224385  0.639512
# COST                                       0.431956  0.139522  0.496460
# GOOG                                       0.824391  0.272740  0.682227
#
#                               S&P 500      AAPL      COST      GOOG
# SOROS FUND MANAGEMENT LLC    0.876981  0.609126  0.518175  0.682919
# PAULSON & CO.INC.            0.766680  0.544949  0.496810  0.554123
# TIGER GLOBAL MANAGEMENT LLC  0.481030  0.334864  0.353235  0.291055
# BERKSHIRE HATHAWAY INC       0.852303  0.694062  0.431956  0.824391
# Algo 1                       0.289358  0.224385  0.139522  0.272740
# Algo 2                       0.875721  0.639512  0.496460  0.682227
# S&P 500                      1.000000  0.759909  0.590297  0.792070
# AAPL                         0.759909  1.000000  0.433918  0.692497
# COST                         0.590297  0.433918  1.000000  0.410074
# GOOG                         0.792070  0.692497  0.410074  1.000000
